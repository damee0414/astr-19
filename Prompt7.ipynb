# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,1,0.01)

def exp(x):
    y = np.exp(x)
    return y

# %%
y = exp(x)

plt.plot(x,y)
plt.xlabel("Time[milliseconds]")
plt.ylabel("Awesomeness")

plt.savefig("prompt7.pdf")
