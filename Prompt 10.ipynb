# %%
import matplotlib.pyplot as plt
import numpy as np

n, p = 10, .25
x = np.random.binomial(n, p, 1000)

plt.hist(x, bins = 100, edgecolor = 'white')
plt.xlabel("x")
plt.ylabel("random number")
plt.savefig("promt10.pdf")
